# %%
from liveEvaluation import stream
import time
import pandas as pd
import requests

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
# !pip3 install rqdatac
# Out:
# Collecting rqdatac
#   Downloading rqdatac-2.9.35-cp38-cp38-macosx_10_9_x86_64.whl (184 kB)
#      |████████████████████████████████| 184 kB 6.9 MB/s eta 0:00:01
# Collecting msgpack>=0.5.2
#   Downloading msgpack-1.0.2-cp38-cp38-macosx_10_14_x86_64.whl (72 kB)
#      |████████████████████████████████| 72 kB 3.7 MB/s  eta 0:00:01
# Collecting python-rapidjson
#   Downloading python_rapidjson-1.4-cp38-cp38-macosx_10_9_x86_64.whl (206 kB)
#      |████████████████████████████████| 206 kB 10.8 MB/s eta 0:00:01
# Collecting SQLAlchemy
#   Downloading SQLAlchemy-1.4.22-cp38-cp38-macosx_10_14_x86_64.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 8.5 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/site-packages (from rqdatac) (1.2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.8/site-packages (from rqdatac) (1.15.0)
# Requirement already satisfied: python-dateutil in /Users/ngoyuko/Library/Python/3.8/lib/python/site-packages (from rqdatac) (2.8.1)
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 6.9 MB/s  eta 0:00:01
# Collecting brotli
#   Downloading Brotli-1.0.9-cp38-cp38-macosx_10_9_x86_64.whl (421 kB)
#      |████████████████████████████████| 421 kB 13.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.8/site-packages (from pandas->rqdatac) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/site-packages (from pandas->rqdatac) (2021.1)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.0-cp38-cp38-macosx_10_14_x86_64.whl (87 kB)
#      |████████████████████████████████| 87 kB 10.2 MB/s eta 0:00:01
# Installing collected packages: greenlet, SQLAlchemy, python-rapidjson, pymysql, msgpack, brotli, rqdatac
# Successfully installed SQLAlchemy-1.4.22 brotli-1.0.9 greenlet-1.1.0 msgpack-1.0.2 pymysql-1.0.2 python-rapidjson-1.4 rqdatac-2.9.35
# WARNING: You are using pip version 21.1.2; however, version 21.2.2 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
for j in range(1, 49):
    url = f'http://fund.eastmoney.com/Data/Fund_JJJZ_Data.aspx?t=1&lx=1&letter=&gsid=&text=&sort=zdf,desc&page={j},200'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/21.0.1180.71 Safari/537.1 LBBROWSER'
    }
    resp = requests.get(url, headers=headers).text
    str_ = resp[102:]
    list1 = eval(str_.split(",count")[0])
    print(f'正在爬取第{j}页')
    print(f'本页爬取{len(list1)}条数据')

    num = []
    name = []
    today_price = []
    yesterday_price = []
    day_value = []
    day_value_rate = []
    subscription_status = []
    redemption_status = []
    service_charge = []

    for i in range(len(list1)):
      # 1、基金代码号
        num.append(list1[i][0])
        # 2、股票名称
        name.append(list1[i][1])
  # 3、今日基金净额
        today_price.append(list1[i][3])
        # 4、昨日基金净额
        yesterday_price.append(list1[i][5])
        # 5、日增长值
        day_value.append(list1[i][7])
        # 6、日增长率
        day_value_rate.append(list1[i][8])
        # 7、申购状态
        subscription_status.append(list1[i][9])
        # 8、赎回状态
        redemption_status.append(list1[i][10])
        # 9、手续费
        service_charge.append(list1[i][17])

    df = pd.DataFrame()
    df['基金代码'] = num
    df['基金名称'] = name
    df['2020-08-12\n单位净值'] = today_price
    df['2020-08-11\n单位净值'] = yesterday_price
    df['日增长值'] = day_value
    df['日增长率\n%'] = day_value_rate
    df['申购状态'] = subscription_status
    df['赎回状态'] = redemption_status
    df['手续费'] = service_charge
# Out:
# 正在爬取第1页
# 本页爬取200条数据
# 正在爬取第2页
# 本页爬取200条数据
# 正在爬取第3页
# 本页爬取200条数据
# 正在爬取第4页
# 本页爬取200条数据
# 正在爬取第5页
# 本页爬取200条数据
# 正在爬取第6页
# 本页爬取200条数据
# 正在爬取第7页
# 本页爬取200条数据
# 正在爬取第8页
# 本页爬取200条数据
# 正在爬取第9页
# 本页爬取200条数据
# 正在爬取第10页
# 本页爬取200条数据
# 正在爬取第11页
# 本页爬取200条数据
# 正在爬取第12页
# 本页爬取200条数据
# 正在爬取第13页
# 本页爬取200条数据
# 正在爬取第14页
# 本页爬取200条数据
# 正在爬取第15页
# 本页爬取200条数据
# 正在爬取第16页
# 本页爬取200条数据
# 正在爬取第17页
# 本页爬取200条数据
# 正在爬取第18页
# 本页爬取200条数据
# 正在爬取第19页
# 本页爬取200条数据
# 正在爬取第20页
# 本页爬取200条数据
# 正在爬取第21页
# 本页爬取200条数据
# 正在爬取第22页
# 本页爬取200条数据
# 正在爬取第23页
# 本页爬取200条数据
# 正在爬取第24页
# 本页爬取200条数据
# 正在爬取第25页
# 本页爬取200条数据
# 正在爬取第26页
# 本页爬取200条数据
# 正在爬取第27页
# 本页爬取200条数据
# 正在爬取第28页
# 本页爬取200条数据
# 正在爬取第29页
# 本页爬取200条数据
# 正在爬取第30页
# 本页爬取200条数据
# 正在爬取第31页
# 本页爬取200条数据
# 正在爬取第32页
# 本页爬取200条数据
# 正在爬取第33页
# 本页爬取200条数据
# 正在爬取第34页
# 本页爬取200条数据
# 正在爬取第35页
# 本页爬取200条数据
# 正在爬取第36页
# 本页爬取200条数据
# 正在爬取第37页
# 本页爬取200条数据
# 正在爬取第38页
# 本页爬取200条数据
# 正在爬取第39页
# 本页爬取200条数据
# 正在爬取第40页
# 本页爬取200条数据
# 正在爬取第41页
# 本页爬取200条数据
# 正在爬取第42页
# 本页爬取200条数据
# 正在爬取第43页
# 本页爬取200条数据
# 正在爬取第44页
# 本页爬取200条数据
# 正在爬取第45页
# 本页爬取200条数据
# 正在爬取第46页
# 本页爬取200条数据
# 正在爬取第47页
# 本页爬取200条数据
# 正在爬取第48页
# 本页爬取200条数据

# %%
df
# Out:
#        基金代码          基金名称 2020-08-12\n单位净值 2020-08-11\n单位净值     日增长值 日增长率\n%  \
# 0    007193     恒越核心精选混合C           2.8966           3.0031  -0.1065   -3.55
# 1    006299     恒越核心精选混合A           2.8934           2.9998  -0.1064   -3.55
# 2    002537    平安安盈灵活配置混合           2.8779           2.9838  -0.1059   -3.55
# 3    005545  中银改革红利灵活配置混合           2.4636           2.5544  -0.0908   -3.55
# 4    006227     华宝科技先锋混合A           2.1644           2.2441  -0.0797   -3.55
# ..      ...           ...              ...              ...      ...     ...
# 195  010793     华安成长先锋混合C           1.3191           1.3767  -0.0576   -4.18
# 196  005743       长安裕隆混合A           3.6612           3.8216  -0.1604   -4.20
# 197  005744       长安裕隆混合C           3.6173           3.7758  -0.1585   -4.20
# 198  004205  东方支柱产业灵活配置混合           1.2448           1.2994  -0.0546   -4.20
# 199  005342       长安裕泰混合C           3.1953           3.3359  -0.1406   -4.21
#
#      申购状态  赎回状态    手续费
# 0    开放申购  开放赎回  0.00%
# 1    开放申购  开放赎回  0.15%
# 2    开放申购  开放赎回  0.12%
# 3    开放申购  开放赎回  0.15%
# 4    开放申购  开放赎回  0.15%
# ..    ...   ...    ...
# 195  开放申购  开放赎回  0.00%
# 196  开放申购  开放赎回  0.15%
# 197  开放申购  开放赎回  0.00%
# 198  开放申购  开放赎回  0.15%
# 199  开放申购  开放赎回  0.00%
#
# [200 rows x 9 columns]
